# %% [markdown]
# # PART ONE

# %% [markdown]
# This data was sourced from kaggle. Zack Thoutt scraped the website called winemag.com after watching 'somm', a documentary on master sommelier(the ability to identify wines through blind tasting)
# This data is available under the Creative commons,Attribution and Share-Alike license and I do not own this data.It is being used for educational purposes only https://www.kaggle.com/zynicide/wine-reviews

# %% [markdown]
# # Import libraries and dependencies

# %%
import requests
import json
import sys
sys.path.append('./')
from config import gkey

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from IPython.display import display
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.notebook_repr_html',True)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# # Read in file and remove unwanted columns

# %%
wineData = pd.read_csv('winemag_data.csv')
wineData = wineData.drop(columns=['Unnamed: 0', 'region_2', 'designation'], axis=1)
wineData.head()
# Out:
#     country                                        description  points  price  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...      87    nan
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      87  15.00
# 2        US  Tart and snappy, the flavors of lime flesh and...      87  14.00
# 3        US  Pineapple rind, lemon pith and orange blossom ...      87  13.00
# 4        US  Much like the regular bottling from 2012, this...      87  65.00
#
#             province             region_1         taster_name  \
# 0  Sicily & Sardinia                 Etna       Kerin O’Keefe
# 1              Douro                  NaN          Roger Voss
# 2             Oregon    Willamette Valley        Paul Gregutt
# 3           Michigan  Lake Michigan Shore  Alexander Peartree
# 4             Oregon    Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %% [markdown]
# #We will go through the title column and extract the year the wine is produced. We see a pattern of the year included in most if not all of the tasters reviews. We will use the isdigit() method in python which identifies numerical digits in strings. We will append this to a new list and use this for our analysis later on.

# %%
#Extract year from Title to get year column
title_list = [title for title in wineData["title"]]

def hasNumbers(stringsList):
    return any(char.isdigit() for char in stringsList) 

counter = 0
years = []

for title in title_list:
    strings_list = []
    numbers_list = []
    years_list = []
    
    for ele in title.split(' '):
        strings_list.append(ele)
    if hasNumbers(strings_list) == True:
        for x in strings_list:
            if x.isdigit():
                numbers_list.append(int(x))
        years_list = [year for year in numbers_list if 1980 < year < 2020]
        #if the years list contains more than one element, append only the first one
        if len(years_list) >= 1:
            years.append(years_list[0]) 
        elif len(years_list) == 0:
            years.append("N/A")
    if hasNumbers(strings_list) == False:
        years.append("N/A")
    counter = counter + 1

# %%
#add the year list to the dataframe
wineData['year'] = years
wineData.head()
# Out:
#     country                                        description  points  price  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...      87    nan
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      87  15.00
# 2        US  Tart and snappy, the flavors of lime flesh and...      87  14.00
# 3        US  Pineapple rind, lemon pith and orange blossom ...      87  13.00
# 4        US  Much like the regular bottling from 2012, this...      87  65.00
#
#             province             region_1         taster_name  \
# 0  Sicily & Sardinia                 Etna       Kerin O’Keefe
# 1              Douro                  NaN          Roger Voss
# 2             Oregon    Willamette Valley        Paul Gregutt
# 3           Michigan  Lake Michigan Shore  Alexander Peartree
# 4             Oregon    Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery  year
# 0     White Blend              Nicosia  2013
# 1  Portuguese Red  Quinta dos Avidagos  2011
# 2      Pinot Gris            Rainstorm  2013
# 3        Riesling           St. Julian  2013
# 4      Pinot Noir         Sweet Cheeks  2012

# %%
#rename null values as N/A to easily drop them
wineData = wineData.fillna('N/A')

# %% [markdown]
# # Use Google's api to append latitudinal and longitudinal points

# %%
#create a new column called Location
wineData['Location'] = wineData[['province','country']].apply(lambda x: ','.join(x), axis=1)
wineData.head()
# Out:
#     country                                        description  points price  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...      87   N/A
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      87 15.00
# 2        US  Tart and snappy, the flavors of lime flesh and...      87 14.00
# 3        US  Pineapple rind, lemon pith and orange blossom ...      87 13.00
# 4        US  Much like the regular bottling from 2012, this...      87 65.00
#
#             province             region_1         taster_name  \
# 0  Sicily & Sardinia                 Etna       Kerin O’Keefe
# 1              Douro                  N/A          Roger Voss
# 2             Oregon    Willamette Valley        Paul Gregutt
# 3           Michigan  Lake Michigan Shore  Alexander Peartree
# 4             Oregon    Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   N/A  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery  year                 Location
# 0     White Blend              Nicosia  2013  Sicily & Sardinia,Italy
# 1  Portuguese Red  Quinta dos Avidagos  2011           Douro,Portugal
# 2      Pinot Gris            Rainstorm  2013                Oregon,US
# 3        Riesling           St. Julian  2013              Michigan,US
# 4      Pinot Noir         Sweet Cheeks  2012                Oregon,US

# %%
#use the google location api to collect lat and lng points for plotting later
combined_location = []
lat_lng = []

for l in wineData['Location']:
    #append non dups only
    if l not in combined_location:
        combined_location.append(l)
        

for location in combined_location:
    target_location = location
    target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(target_location, gkey)
    
    response = requests.get(target_url).json()
    lat_lng.append(response)

# %%
lats = []
lngs = []

for index, point in enumerate(lat_lng): 
    try:
        lat = lat_lng[index]['results'][0]['geometry']['location']['lat']
        lats.append(lat)
        lng = lat_lng[index]['results'][0]['geometry']['location']['lng']
        lngs.append(lng)
        
    except:
        lats.append('N/A')
        lngs.append('N/A')

# %%
# Create a new df and added lat and lng values
dict1 = {'Location':combined_location,
               'Latitude': lats,
               'Longitude': lngs}

coord_data = pd.DataFrame(dict1)
coord_data
# Out:
#                            Location Latitude Longitude
# 0           Sicily & Sardinia,Italy    37.60     14.02
# 1                    Douro,Portugal    41.50     -5.51
# 2                         Oregon,US    43.80   -120.55
# 3                       Michigan,US    44.31    -85.60
# 4              Northern Spain,Spain    42.82     -1.64
# ..                              ...      ...       ...
# 421  Vin de Pays de Velvendo,Greece    40.25     22.07
# 422          Landwein Rhein,Germany    49.23      8.39
# 423                   Lesbos,Greece    39.26     26.28
# 424          Távora-Varosa,Portugal    41.04     -7.76
# 425           Neuchâtel,Switzerland    46.99      6.93
#
# [426 rows x 3 columns]

# %%
#merge the location data with the existing wine_data dataFrame 
wine_data = pd.merge(wineData, coord_data, on='Location', how='inner')
wine_data.head()
# Out:
#   country                                        description  points price  \
# 0   Italy  Aromas include tropical fruit, broom, brimston...      87   N/A
# 1   Italy  Here's a bright, informal red that opens with ...      87 16.00
# 2   Italy  This is dominated by oak and oak-driven aromas...      87   N/A
# 3   Italy  Delicate aromas recall white flower and citrus...      87 19.00
# 4   Italy  Aromas of prune, blackcurrant, toast and oak c...      87 35.00
#
#             province  region_1    taster_name taster_twitter_handle  \
# 0  Sicily & Sardinia      Etna  Kerin O’Keefe          @kerinokeefe
# 1  Sicily & Sardinia  Vittoria  Kerin O’Keefe          @kerinokeefe
# 2  Sicily & Sardinia      Etna  Kerin O’Keefe          @kerinokeefe
# 3  Sicily & Sardinia   Sicilia  Kerin O’Keefe          @kerinokeefe
# 4  Sicily & Sardinia   Sicilia  Kerin O’Keefe          @kerinokeefe
#
#                                                title            variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)        White Blend
# 1   Terre di Giurfo 2013 Belsito Frappato (Vittoria)           Frappato
# 2             Masseria Setteporte 2012 Rosso  (Etna)  Nerello Mascalese
# 3  Baglio di Pianetto 2007 Ficiligno White (Sicilia)        White Blend
# 4        Canicattì 2009 Aynat Nero d'Avola (Sicilia)       Nero d'Avola
#
#                 winery  year                 Location Latitude Longitude
# 0              Nicosia  2013  Sicily & Sardinia,Italy    37.60     14.02
# 1      Terre di Giurfo  2013  Sicily & Sardinia,Italy    37.60     14.02
# 2  Masseria Setteporte  2012  Sicily & Sardinia,Italy    37.60     14.02
# 3   Baglio di Pianetto  2007  Sicily & Sardinia,Italy    37.60     14.02
# 4            Canicattì  2009  Sicily & Sardinia,Italy    37.60     14.02

# %%
# clean the column names  
wine_data.columns= ['Country', 'Title','Points','Price', 'Province','Region','Taster Name',

                    'Twitter Handle','Description','Variety','Winery','Year','Location','Latitude','Longitude']
print(len(wine_data))
wine_data.head()
# Out:
# 129971
#   Country                                              Title  Points Price  \
# 0   Italy  Aromas include tropical fruit, broom, brimston...      87   N/A
# 1   Italy  Here's a bright, informal red that opens with ...      87 16.00
# 2   Italy  This is dominated by oak and oak-driven aromas...      87   N/A
# 3   Italy  Delicate aromas recall white flower and citrus...      87 19.00
# 4   Italy  Aromas of prune, blackcurrant, toast and oak c...      87 35.00
#
#             Province    Region    Taster Name Twitter Handle  \
# 0  Sicily & Sardinia      Etna  Kerin O’Keefe   @kerinokeefe
# 1  Sicily & Sardinia  Vittoria  Kerin O’Keefe   @kerinokeefe
# 2  Sicily & Sardinia      Etna  Kerin O’Keefe   @kerinokeefe
# 3  Sicily & Sardinia   Sicilia  Kerin O’Keefe   @kerinokeefe
# 4  Sicily & Sardinia   Sicilia  Kerin O’Keefe   @kerinokeefe
#
#                                          Description            Variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)        White Blend
# 1   Terre di Giurfo 2013 Belsito Frappato (Vittoria)           Frappato
# 2             Masseria Setteporte 2012 Rosso  (Etna)  Nerello Mascalese
# 3  Baglio di Pianetto 2007 Ficiligno White (Sicilia)        White Blend
# 4        Canicattì 2009 Aynat Nero d'Avola (Sicilia)       Nero d'Avola
#
#                 Winery  Year                 Location Latitude Longitude
# 0              Nicosia  2013  Sicily & Sardinia,Italy    37.60     14.02
# 1      Terre di Giurfo  2013  Sicily & Sardinia,Italy    37.60     14.02
# 2  Masseria Setteporte  2012  Sicily & Sardinia,Italy    37.60     14.02
# 3   Baglio di Pianetto  2007  Sicily & Sardinia,Italy    37.60     14.02
# 4            Canicattì  2009  Sicily & Sardinia,Italy    37.60     14.02

# %%
#Remove rows from columns price, province,points, lat and lng with N/A values
wine_data = wine_data.loc[wine_data['Price'] != 'N/A']
wine_data = wine_data.loc[wine_data['Province'] != 'N/A']  
wine_data = wine_data.loc[wine_data['Year'] != 'N/A']
wine_data = wine_data.loc[wine_data['Latitude'] !='N/A']
wine_data = wine_data.loc[wine_data['Longitude'] !='N/A']

wine_data.shape
# Out:
# (114589, 15)

# %%
# Get the unique names in wine variety to group wine by category
wine_data['Variety'].unique()
# Out:
# array(['Frappato', 'White Blend', "Nero d'Avola", 'Red Blend',
#        'Cabernet Sauvignon', 'Catarratto', 'Inzolia', 'Monica', 'Grillo',
#        'Nerello Mascalese', 'Cannonau', 'Carricante', 'Rosato',
#        'Pinot Noir', 'Syrah', 'Insolia', 'Chardonnay', 'Zibibbo', 'Fiano',
#        'Rosé', 'Vermentino', 'Sauvignon', 'Albanello', 'Perricone',
#        'Carignano', 'Torbato', 'Cabernet Franc', 'Merlot', 'Moscato',
#        'Sauvignon Blanc', 'Pinot Nero', 'Nerello Cappuccio', 'Malvasia',
#        'Grecanico', 'Pinot Grigio', 'Nuragus', 'Sangiovese', 'Shiraz',
#        'Bovale', 'Mondeuse', 'Tannat', 'Cabernet Blend', 'Viognier',
#        'Nasco', 'Alicante', 'Müller-Thurgau', 'Moscato di Noto',
#        'Francisa', 'Cabernet Sauvignon-Shiraz', 'Portuguese Red',
#        'Portuguese White', 'Sousão', 'Touriga Nacional',
#        'Portuguese Sparkling', 'Tinta Barroca', 'Tinta Roriz',
#        'Touriga Franca', 'Portuguese Rosé', 'Touriga Nacional Blend',
#        'Códega do Larinho', 'Viosinho', 'Tinta Francisca', 'Siria',
#        'Gouveio', 'Moscatel', 'Sémillon', 'Port', 'Bastardo', 'Rabigato',
#        'Malvasia Fina', 'Verdelho', 'Pinot Gris', 'Pinot Blanc',
#        'Sparkling Blend', 'Grenache', 'Grüner Veltliner', 'Riesling',
#        'Albariño', 'Malbec', 'Claret', 'G-S-M', 'Marsanne-Roussanne',
#        'Carmenère', 'Rhône-style White Blend', 'Gamay Noir',
#        'Gewürztraminer-Riesling', 'Auxerrois', 'Tempranillo',
#        'Cabernet Franc-Merlot', 'Dolcetto', 'Zinfandel',
#        'Bordeaux-style Red Blend', 'Gewürztraminer', 'Petit Verdot',
#        'Mourvèdre', 'Rhône-style Red Blend', 'Baco Noir', 'Muscat',
#        'Arneis', 'Roussanne-Viognier', 'Primitivo',
#        'Viognier-Gewürztraminer', 'Syrah-Grenache', 'Semillon-Chardonnay',
#        'Cabernet Sauvignon-Merlot', 'Grenache Blanc', 'Petite Sirah',
#        'Tempranillo-Garnacha', 'Pinot Blanc-Pinot Noir',
#        'Cabernet Sauvignon-Syrah', 'Champagne Blend', 'Malbec-Tannat',
#        'Pinot Meunier', 'Garnacha', 'Muscat Canelli', 'Meritage',
#        'Lagrein', 'Pinot Auxerrois', 'Pinot Noir-Syrah', 'Chenin Blanc',
#        'Gamay', 'Pinotage', 'Edelzwicker', 'Tempranillo-Syrah', 'Cayuga',
#        'Tinta Amarela', 'White Riesling', 'Syrah-Cabernet', 'Melon',
#        'Viognier-Marsanne', 'Roussanne', 'Pinot-Chardonnay', 'Graciano',
#        'Chardonnay-Pinot Blanc', 'Semillon-Sauvignon Blanc',
#        'Cabernet Merlot', 'Traminette', 'Syrah-Viognier', 'Vignoles',
#        'Merlot-Cabernet Franc', 'Lemberger', 'Tempranillo-Merlot',
#        'Tempranillo Blend', 'Verdejo', 'Mencía', 'Viura', 'Verdejo-Viura',
#        'Viura-Chardonnay', 'Tinta de Toro', 'Tinta Fina', 'Maturana',
#        'Rosado', 'Godello', 'Tinto Fino',
#        'Tempranillo-Cabernet Sauvignon', 'Cabernet Sauvignon-Tempranillo',
#        'Tinto del Pais', 'Garnacha Blanca', 'Prieto Picudo',
#        'Garnacha Tintorera', 'Macabeo', 'Mazuelo', 'Tinta del Pais',
#        'Viura-Verdejo', 'Tinta del Toro', 'Garnacha-Syrah', 'Carineña',
#        'Tempranillo Blanco', 'Hondarrabi Zuri', 'Tempranillo-Shiraz',
#        'Malvasia-Viura', 'Grenache-Syrah', 'Verdejo-Sauvignon Blanc',
#        'Grenache Blend', 'Garnacha-Monastrell', 'Garnacha Blend',
#        'Vidadillo', 'Macabeo-Chardonnay', 'Jaen',
#        'Sauvignon Blanc-Verdejo', 'Garnacha-Tempranillo',
#        'Merlot-Cabernet Sauvignon', 'Shiraz-Tempranillo',
#        'Garnacha-Cabernet', 'Parraleta', 'Alsace white blend', 'Sylvaner',
#        'Chasselas', 'Tokay Pinot Gris', 'Fumé Blanc', 'Marsanne',
#        'Muscat Blanc à Petits Grains', 'Charbono', 'Barbera', 'Teroldego',
#        'Sauvignon Blanc-Semillon', 'Syrah-Petite Sirah', 'Nebbiolo',
#        'Colombard', 'Muskat', 'Bordeaux-style White Blend', 'Falanghina',
#        'Chardonnay-Semillon', 'Cinsault', 'Carignan', 'Symphony',
#        'Black Muscat', 'Valdiguié', 'Syrah-Mourvèdre', 'Petite Verdot',
#        'Merlot-Malbec', 'Clairette', 'Malbec-Syrah', 'Monastrell',
#        'Scheurebe', 'Aglianico', 'Trousseau Gris', 'Sagrantino', 'Greco',
#        'Muscat Blanc', 'Cabernet Sauvignon-Cabernet Franc',
#        'Syrah-Cabernet Sauvignon', 'Montepulciano',
#        'Chenin Blanc-Viognier', 'Carignane', 'Grenache-Mourvèdre',
#        'Syrah-Tempranillo', 'Cabernet Sauvignon-Barbera', 'Refosco',
#        'Sangiovese-Cabernet Sauvignon', 'Sangiovese Cabernet',
#        'Chardonnay-Viognier', 'Mataro', 'Cortese', 'Mourvèdre-Syrah',
#        'Ugni Blanc', 'Aligoté', 'Picpoul', 'Marsanne-Viognier',
#        'Alvarelhão', 'Viognier-Chardonnay', 'Muscat Hamburg',
#        'Johannisberg Riesling', 'Orange Muscat', 'Sauvignon Musqué',
#        'Ribolla Gialla', 'Roussanne-Marsanne', 'Blaufränkisch',
#        'Sangiovese-Syrah', 'Mission', 'Trebbiano', 'Counoise',
#        'Tocai Friulano', 'Cabernet Sauvignon-Carmenère',
#        'Malvasia Bianca', 'Negrette', 'Torrontés',
#        'Cabernet Sauvignon-Sangiovese', 'Alicante Bouschet',
#        'Syrah-Cabernet Franc', 'Syrah-Merlot', 'Abouriou',
#        'Syrah-Petit Verdot', 'Viognier-Roussanne', 'Souzao',
#        'Sauvignon Gris', 'Muscadine', 'Syrah-Grenache-Viognier',
#        'Negroamaro', 'Dornfelder', 'Moscato Giallo', 'Cabernet Pfeffer',
#        'Cabernet Sauvignon-Malbec', 'Pinot Blanc-Viognier',
#        'Cabernet-Shiraz', 'Roussanne-Grenache Blanc', 'Grenache Noir',
#        'Viognier-Grenache Blanc', 'Kerner', 'Tinta Madeira',
#        'Merlot-Cabernet', 'Cabernet', 'Pinot Blanc-Chardonnay',
#        'Chardonnay-Albariño', 'Silvaner', 'Viognier-Valdiguié',
#        'Prosecco', 'Tannat-Syrah', "Muscat d'Alexandrie", 'Alvarinho',
#        'Spätburgunder', 'Elbling', 'Weissburgunder',
#        'Malbec-Cabernet Sauvignon', 'Bonarda', 'Malbec-Bonarda',
#        'Trousseau', 'Malbec-Cabernet', 'Malbec-Merlot',
#        'Malbec-Cabernet Franc', 'Tocai', 'Malbec-Petit Verdot',
#        'Chenin Blanc-Chardonnay', 'Cabernet Franc-Malbec', 'Syrah-Malbec',
#        'Cabernet-Syrah', 'Cabernet Franc-Cabernet Sauvignon',
#        'Malbec Blend', 'Chardonnay-Sauvignon', 'Cabernet-Malbec',
#        'Syrah-Bonarda', 'Malbec-Tempranillo', 'Shiraz-Malbec',
#        'Muskat Ottonel', 'Chambourcin', 'Petit Manseng', 'Vidal',
#        'Touriga', 'Vidal Blanc', 'Seyval Blanc', 'Rkatsiteli', 'Norton',
#        'Merlot-Petite Verdot', 'Carmenère-Cabernet Sauvignon',
#        'Carmenère-Syrah', 'Cabernet Franc-Carmenère', 'País',
#        'Syrah-Carignan', 'Torontel', 'Sauvignon-Sémillon', 'Muscadelle',
#        'N/A', 'Grenache-Carignan', 'Siegerrebe', 'Barbera-Nebbiolo',
#        'Madeleine Angevine', 'Pinot Gris-Gewürztraminer', 'Zweigelt',
#        'Morio Muskat', 'Sangiovese Grosso', 'Carignan-Grenache',
#        'Verdicchio', 'Lambrusco di Sorbara', 'Cesanese', 'Pecorino',
#        'Albana', 'Grechetto', 'Lambrusco Grasparossa', 'Passerina',
#        'Trebbiano Spoletino', 'Lambrusco', "Cesanese d'Affile",
#        'Pignoletto', 'Cococciola', 'Lambrusco Salamino',
#        'Malvasia di Candia', 'Biancale', 'Verdeca', 'Pinot Noir-Gamay',
#        'Sacy', 'Chardonnay-Pinot Gris', 'Colombard-Ugni Blanc',
#        'Shiraz-Cabernet Sauvignon', 'Shiraz-Viognier', 'Shiraz-Grenache',
#        'Shiraz-Cabernet', 'Grenache-Shiraz',
#        'Cabernet Sauvignon-Merlot-Shiraz', 'Shiraz-Roussanne', 'Savagnin',
#        'Shiraz-Mourvèdre', 'Tinta Miúda', 'Fernão Pires', 'Trincadeira',
#        'Touriga Nacional-Cabernet Sauvignon', 'Arinto', 'Alfrocheiro',
#        'Moscatel Graúdo', 'Treixadura', 'Doña Blanca', 'Vernaccia',
#        'Prugnolo Gentile', 'Pugnitello', 'Aleatico', 'Moscadello',
#        'Ciliegiolo', 'Pinot Bianco', 'Canaiolo', 'Malvasia Nera',
#        'Vermentino Nero', 'Ansonica', 'Colorino', 'Traminer',
#        'Austrian Red Blend', 'Welschriesling', 'St. Laurent', 'Neuburger',
#        'Blauburgunder', 'Austrian white blend',
#        'Sauvignon Blanc-Chardonnay', 'Sämling', 'Furmint',
#        'Chardonnay Weissburgunder', 'Diamond', 'Marquette',
#        'Riesling-Chardonnay', 'Chardonnay-Riesling', 'Saperavi',
#        'Chelois', 'Pinot Grigio-Sauvignon Blanc', 'Valvin Muscat',
#        'Chancellor', 'Cabernet Franc-Lemberger', 'Ruché', 'Nascetta',
#        'Freisa', 'Brachetto', 'Timorasso', 'Grignolino', 'Vespolina',
#        'Erbaluce', 'Albarossa', 'Uvalino', 'Favorita',
#        'Chenin Blanc-Sauvignon Blanc', 'Sauvignon Blanc-Chenin Blanc',
#        'Antão Vaz', 'Aragonez', 'Castelão', 'Tinta Cao', 'Aragonês',
#        'Baga', 'Rufete', 'Tinto Velasco', 'Macabeo-Moscatel', 'Malvar',
#        'Airen', 'Bobal', 'Tannat-Cabernet', 'Ugni Blanc-Colombard',
#        'Colombard-Sauvignon Blanc', 'Gros and Petit Manseng', 'Mauzac',
#        'Merlot-Tannat', 'Gros Manseng', 'Duras', "Loin de l'Oeil",
#        'Chardonnay-Sauvignon Blanc', 'Mansois', 'Tannat-Cabernet Franc',
#        'Fer Servadou', 'Tannat-Merlot', 'Braucol', 'Muscadel',
#        'Petit Courbu', 'Ondenc', 'Friulano', 'Verduzzo', 'Nosiola',
#        'Schiava', 'Veltliner', 'Vitovska', 'Picolit',
#        'Verduzzo Friulano ', 'Groppello', 'Corvina', 'Glera',
#        'Incrocio Manzoni', 'Rebo', 'Malvasia Istriana', 'Manzoni',
#        'Teroldego Rotaliano', 'Marzemino', 'Moscato Rosa', 'Pignolo',
#        'Garganega', 'Corvina, Rondinella, Molinara', 'Durella', 'Raboso',
#        'Vespaiolo', 'Franconia', 'Marawi', 'Marselan', 'Maria Gomes',
#        'Cerceal', 'Tokaji', 'Hárslevelü', 'Assyrtico', 'Assyrtiko',
#        'Mavrotragano', 'Xarel-lo', 'Pansa Blanca', 'Trepat',
#        'Cariñena-Garnacha', 'Paralleda', 'Picapoll', 'Garnacha-Cariñena',
#        'Pedro Ximénez', 'Feteascǎ Regalǎ', 'Muscatel', 'Carignan-Syrah',
#        'Grenache Gris', 'Provence red blend', 'Provence white blend',
#        'Rolle', 'Durif', 'Xinomavro', 'Prié Blanc', 'Centesimino',
#        'Gelber Muskateller', 'Roter Veltliner', 'Nielluciu',
#        'Gelber Traminer', 'Gros Plant', 'Romorantin', 'Grolleau',
#        'Folle Blanche', 'Turbiana', 'Trebbiano di Lugana', 'Morillon',
#        'Vilana', 'Thrapsathiri', 'Plyto', 'Dafni', 'Kotsifali',
#        'Mandilaria', 'Avesso', 'Loureiro-Arinto', 'Loureiro', 'Azal',
#        'Vinhão', 'Trajadura', 'Monastrell-Syrah', 'Verdil', 'Forcallà',
#        'Verdosilla', 'Moscatel de Alejandría',
#        'Merseguera-Sauvignon Blanc', 'Monastrell-Petit Verdot',
#        'Bobal-Cabernet Sauvignon', 'Alvarinho-Chardonnay', 'Merlot-Syrah',
#        'Jampal', 'Blanc du Bois', 'Piquepoul Blanc', 'Jacquez',
#        'Moscatel Roxo', 'Rieslaner', 'Silvaner-Traminer', 'Früburgunder',
#        'Feteasca Neagra', 'Tămâioasă Românească', 'Feteasca',
#        'Roter Traminer', 'Grauburgunder', 'Roditis', 'Agiorgitiko',
#        'Malagouzia', 'Muskateller', 'Merlot-Argaman', 'Pigato',
#        'Muscat of Alexandria', 'Sherry', 'Encruzado', 'Kekfrankos',
#        'Blauer Portugieser', 'Kadarka', 'Malbec-Carménère', 'Bical',
#        'Cercial', 'Maria Gomes-Bical', 'Baga-Touriga Nacional',
#        'Listán Negro', 'Premsal', 'Babosa Negro', 'Malagousia',
#        'Moschofilero', 'Moschofilero-Chardonnay', 'Roditis-Moschofilero',
#        'Rivaner', 'Frankovka', 'Ryzlink Rýnský', 'Cabernet Moravia',
#        'Chardonel', 'St. Vincent', 'Meseguera',
#        'Sauvignon Blanc-Assyrtiko', 'Cabernet Sauvignon Grenache',
#        'Trollinger', 'Teran', 'Plavac Mali', 'Kisi', 'Saperavi-Merlot',
#        'Mtsvane', 'Orangetraube', 'Rara Neagra', 'Mavrud', 'Tamianka',
#        'Argaman', 'Bual', 'Tinta Negra Mole', 'Sercial', 'Gamza',
#        'Kangoun', 'Posip', 'Kalecik Karasi', 'Çalkarası', 'Boğazkere',
#        'Okuzgozu', 'Tempranillo-Tannat', 'Rebula', 'Sauvignonasse',
#        'Chinuri', 'Narince', 'Vranec', 'Blatina', 'Merlot-Shiraz',
#        'Sideritis', 'Athiri', 'Blauburger', 'Portuguiser', 'Irsai Oliver',
#        'Žilavka', 'Emir', 'Karalahna', 'Kuntra', 'Mavroudi', 'Tamjanika',
#        'Xynisteri', 'Misket', 'Graševina', 'Robola', 'Aidani',
#        'Mavrokalavryta', 'Pinotage-Merlot', 'Zlahtina',
#        'Malagouzia-Chardonnay', 'Mavrodaphne', 'Savatiano', 'Xinisteri'],
#       dtype=object)

# %%
# Add a new column called Category to df
wine_data['Category'] = ''

# %%
#Assign labels Red to red wines and White to white wines 
wine_data["Category"] = np.where(wine_data["Variety"].str.contains(r'Albanello|Blanc|Gris|Grillo|Blanche|White|Chardonnay|Moscato|Musca| \
           Narince|Riesling|Catarratto|Carricante|Bianco|Semillon|Viognier|Cortese|Gewürztraminer|Fiano|Inzolia|Insolia|Zibibbo|Champagne| \
           Kisi|Sparkling|Tamianka|Mtsvane|Orangetraube|Kangoun|Moschofilero|Prosecco|Liebfraumilch|Hondarrabi|Macabeo|Tamjanika|Xynisteri|Zilavka| \
           |Zlahtina|Athiri|Roussanne|Torbato', case=False), "White", "Red")
wine_data.head()
# Out:
#   Country                                              Title  Points Price  \
# 1   Italy  Here's a bright, informal red that opens with ...      87 16.00
# 3   Italy  Delicate aromas recall white flower and citrus...      87 19.00
# 4   Italy  Aromas of prune, blackcurrant, toast and oak c...      87 35.00
# 5   Italy  Pretty aromas of yellow flower and stone fruit...      87 13.00
# 6   Italy  Aromas recall ripe dark berry, toast and a whi...      87 10.00
#
#             Province           Region    Taster Name Twitter Handle  \
# 1  Sicily & Sardinia         Vittoria  Kerin O’Keefe   @kerinokeefe
# 3  Sicily & Sardinia          Sicilia  Kerin O’Keefe   @kerinokeefe
# 4  Sicily & Sardinia          Sicilia  Kerin O’Keefe   @kerinokeefe
# 5  Sicily & Sardinia  Terre Siciliane  Kerin O’Keefe   @kerinokeefe
# 6  Sicily & Sardinia  Terre Siciliane  Kerin O’Keefe   @kerinokeefe
#
#                                          Description       Variety  \
# 1   Terre di Giurfo 2013 Belsito Frappato (Vittoria)      Frappato
# 3  Baglio di Pianetto 2007 Ficiligno White (Sicilia)   White Blend
# 4        Canicattì 2009 Aynat Nero d'Avola (Sicilia)  Nero d'Avola
# 5       Stemmari 2013 Dalila White (Terre Siciliane)   White Blend
# 6       Stemmari 2013 Nero d'Avola (Terre Siciliane)  Nero d'Avola
#
#                Winery  Year                 Location Latitude Longitude  \
# 1     Terre di Giurfo  2013  Sicily & Sardinia,Italy    37.60     14.02
# 3  Baglio di Pianetto  2007  Sicily & Sardinia,Italy    37.60     14.02
# 4           Canicattì  2009  Sicily & Sardinia,Italy    37.60     14.02
# 5            Stemmari  2013  Sicily & Sardinia,Italy    37.60     14.02
# 6            Stemmari  2013  Sicily & Sardinia,Italy    37.60     14.02
#
#   Category
# 1      Red
# 3    White
# 4      Red
# 5    White
# 6      Red

# %% [markdown]
# # Remove Countries that the wine tasters mentioned less than 50 times

# %%
#Replace the name US with United States
wine_data["Country"] = wine_data["Country"].replace(
    {"US": "United States"})

# %%
# We want to see the number of times each country is mentioned 
wine_data['Country'].value_counts()
# Out:
# United States    53351
# France           15892
# Italy            14966
# Spain             6062
# Portugal          4546
# Chile             4391
# Argentina         3714
# Austria           2656
# Australia         2225
# Germany           1827
# New Zealand       1368
# South Africa      1278
# Israel             471
# Greece             425
# Canada             253
# Hungary            142
# Bulgaria           141
# Romania            111
# Uruguay            108
# Georgia             81
# Slovenia            78
# Turkey              74
# Mexico              70
# Croatia             57
# Moldova             57
# England             55
# Name: Country, dtype: int64

# %%
#remove countries with less than 50 mentions
from collections import Counter

counts = Counter(wine_data.Country)
wine_data = wine_data[wine_data.Country.isin([num for num in counts if counts[num] > 50])]
wine_data = wine_data.reset_index()

# %%
wine_data = wine_data.drop('index', axis=1)

# %%
wine_data.head()
# Out:
#   Country                                              Title  Points Price  \
# 0   Italy  Here's a bright, informal red that opens with ...      87 16.00
# 1   Italy  Delicate aromas recall white flower and citrus...      87 19.00
# 2   Italy  Aromas of prune, blackcurrant, toast and oak c...      87 35.00
# 3   Italy  Pretty aromas of yellow flower and stone fruit...      87 13.00
# 4   Italy  Aromas recall ripe dark berry, toast and a whi...      87 10.00
#
#             Province           Region    Taster Name Twitter Handle  \
# 0  Sicily & Sardinia         Vittoria  Kerin O’Keefe   @kerinokeefe
# 1  Sicily & Sardinia          Sicilia  Kerin O’Keefe   @kerinokeefe
# 2  Sicily & Sardinia          Sicilia  Kerin O’Keefe   @kerinokeefe
# 3  Sicily & Sardinia  Terre Siciliane  Kerin O’Keefe   @kerinokeefe
# 4  Sicily & Sardinia  Terre Siciliane  Kerin O’Keefe   @kerinokeefe
#
#                                          Description       Variety  \
# 0   Terre di Giurfo 2013 Belsito Frappato (Vittoria)      Frappato
# 1  Baglio di Pianetto 2007 Ficiligno White (Sicilia)   White Blend
# 2        Canicattì 2009 Aynat Nero d'Avola (Sicilia)  Nero d'Avola
# 3       Stemmari 2013 Dalila White (Terre Siciliane)   White Blend
# 4       Stemmari 2013 Nero d'Avola (Terre Siciliane)  Nero d'Avola
#
#                Winery  Year                 Location Latitude Longitude  \
# 0     Terre di Giurfo  2013  Sicily & Sardinia,Italy    37.60     14.02
# 1  Baglio di Pianetto  2007  Sicily & Sardinia,Italy    37.60     14.02
# 2           Canicattì  2009  Sicily & Sardinia,Italy    37.60     14.02
# 3            Stemmari  2013  Sicily & Sardinia,Italy    37.60     14.02
# 4            Stemmari  2013  Sicily & Sardinia,Italy    37.60     14.02
#
#   Category
# 0      Red
# 1    White
# 2      Red
# 3    White
# 4      Red

# %%
#see the number of unique values in relevant columns and a summary dataframe
country = len(wine_data['Country'].unique())
title = len(wine_data['Title'].unique())
winery = len(wine_data['Winery'].unique())
variety = len(wine_data['Variety'].unique())
price = len(wine_data['Price'].unique())
province=len(wine_data['Province'].unique())
year = len(wine_data['Year'].unique())
grade = len(wine_data['Points'].unique())



df = pd.DataFrame({'Number of Titles': [title],
                   'Number of Countries': [country],
                   'Number of Wineries': [winery],
                   'Variety count': [variety],
                   'Prices count': [price],
                   'Number of provinces': [province],
                   'Year count' : [year],
                   'Wine grades' :[grade]
                  })
                        
df
# Out:
#    Number of Titles  Number of Countries  Number of Wineries  Variety count  \
# 0            105494                   26               15105            629
#
#    Prices count  Number of provinces  Year count  Wine grades
# 0           382                  355          36           21

# %% [markdown]
# # Export as csv file and load to sqlite database

# %%
# save completed and cleaned df and export to csv
wine_data.to_csv('Wine_data.csv')

# %%
# export to sqlite database
from sqlalchemy import create_engine
import sqlite3

engine = create_engine('sqlite:///wine_reviews.db', echo=True)
conn = engine.connect()
# Out:
# 2020-11-08 20:46:13,736 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-11-08 20:46:13,738 INFO sqlalchemy.engine.base.Engine ()
# 2020-11-08 20:46:13,740 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-11-08 20:46:13,741 INFO sqlalchemy.engine.base.Engine ()

# %%
# create table and load dataframe to sqlite db
sqlite_table = 'wine'
wine_data.to_sql(sqlite_table, conn, if_exists='replace')
# Out:
# 2020-11-08 20:46:15,912 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("wine")
# 2020-11-08 20:46:15,914 INFO sqlalchemy.engine.base.Engine ()
# 2020-11-08 20:46:15,917 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("wine")
# 2020-11-08 20:46:15,919 INFO sqlalchemy.engine.base.Engine ()
# 2020-11-08 20:46:15,921 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2020-11-08 20:46:15,923 INFO sqlalchemy.engine.base.Engine ()
# 2020-11-08 20:46:16,219 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("wine")
# 2020-11-08 20:46:16,220 INFO sqlalchemy.engine.base.Engine ()
# 2020-11-08 20:46:16,223 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'wine' AND type = 'table'
# 2020-11-08 20:46:16,224 INFO sqlalchemy.engine.base.Engine ()
# 2020-11-08 20:46:16,226 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("wine")
# 2020-11-08 20:46:16,227 INFO sqlalchemy.engine.base.Engine ()
# 2020-11-08 20:46:16,228 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'wine' AND type = 'table'
# 2020-11-08 20:46:16,229 INFO sqlalchemy.engine.base.Engine ()
# 2020-11-08 20:46:16,232 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("wine")
# 2020-11-08 20:46:16,233 INFO sqlalchemy.engine.base.Engine ()
# 2020-11-08 20:46:16,235 INFO sqlalchemy.engine.base.Engine PRAGMA index_info("ix_wine_index")
# 2020-11-08 20:46:16,237 INFO sqlalchemy.engine.base.Engine ()
# 2020-11-08 20:46:16,239 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("wine")
# 2020-11-08 20:46:16,240 INFO sqlalchemy.engine.base.Engine ()
# 2020-11-08 20:46:16,241 INFO sqlalchemy.engine.base.Engine PRAGMA index_info("ix_wine_index")
# 2020-11-08 20:46:16,243 INFO sqlalchemy.engine.base.Engine ()
# 2020-11-08 20:46:16,245 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'wine' AND type = 'table'
# 2020-11-08 20:46:16,246 INFO sqlalchemy.engine.base.Engine ()
# 2020-11-08 20:46:16,251 INFO sqlalchemy.engine.base.Engine
# DROP TABLE wine
# 2020-11-08 20:46:16,253 INFO sqlalchemy.engine.base.Engine ()
# 2020-11-08 20:46:19,433 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-11-08 20:46:19,437 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE wine (
# 	"index" BIGINT,
# 	"Country" TEXT,
# 	"Title" TEXT,
# 	"Points" BIGINT,
# 	"Price" FLOAT,
# 	"Province" TEXT,
# 	"Region" TEXT,
# 	"Taster Name" TEXT,
# 	"Twitter Handle" TEXT,
# 	"Description" TEXT,
# 	"Variety" TEXT,
# 	"Winery" TEXT,
# 	"Year" BIGINT,
# 	"Location" TEXT,
# 	"Latitude" TEXT,
# 	"Longitude" TEXT,
# 	"Category" TEXT
# )
#
#
# 2020-11-08 20:46:19,438 INFO sqlalchemy.engine.base.Engine ()
# 2020-11-08 20:46:19,550 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-11-08 20:46:19,552 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_wine_index ON wine ("index")
# 2020-11-08 20:46:19,553 INFO sqlalchemy.engine.base.Engine ()
# 2020-11-08 20:46:19,781 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-11-08 20:46:19,961 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-11-08 20:46:22,823 INFO sqlalchemy.engine.base.Engine INSERT INTO wine ("index", "Country", "Title", "Points", "Price", "Province", "Region", "Taster Name", "Twitter Handle", "Description", "Variety", "Winery", "Year", "Location", "Latitude", "Longitude", "Category") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2020-11-08 20:46:22,831 INFO sqlalchemy.engine.base.Engine ((0, 'Italy', "Here's a bright, informal red that opens with aromas of candied berry, white pepper and savory herb that carry over to the palate. It's balanced with fresh acidity and soft tannins.", 87, 16.0, 'Sicily & Sardinia', 'Vittoria', 'Kerin O’Keefe', '@kerinokeefe', 'Terre di Giurfo 2013 Belsito Frappato (Vittoria)', 'Frappato', 'Terre di Giurfo', 2013, 'Sicily & Sardinia,Italy', 37.5999938, 14.0153557, 'Red'), (1, 'Italy', 'Delicate aromas recall white flower and citrus. The palate offers passion fruit, lime and white peach with a hint of mineral alongside bright acidity.', 87, 19.0, 'Sicily & Sardinia', 'Sicilia', 'Kerin O’Keefe', '@kerinokeefe', 'Baglio di Pianetto 2007 Ficiligno White (Sicilia)', 'White Blend', 'Baglio di Pianetto', 2007, 'Sicily & Sardinia,Italy', 37.5999938, 14.0153557, 'White'), (2, 'Italy', 'Aromas of prune, blackcurrant, toast and oak carry through to the extracted palate, along with flavors of black cherry and roasted coffee beans. Firm but drying tannins provide the framework.', 87, 35.0, 'Sicily & Sardinia', 'Sicilia', 'Kerin O’Keefe', '@kerinokeefe', "Canicattì 2009 Aynat Nero d'Avola (Sicilia)", "Nero d'Avola", 'Canicattì', 2009, 'Sicily & Sardinia,Italy', 37.5999938, 14.0153557, 'Red'), (3, 'Italy', 'Pretty aromas of yellow flower and stone fruit lead the nose. The bright palate offers yellow apple, apricot, vanilla and delicate notes of lightly toasted oak alongside crisp acidity.', 87, 13.0, 'Sicily & Sardinia', 'Terre Siciliane', 'Kerin O’Keefe', '@kerinokeefe', 'Stemmari 2013 Dalila White (Terre Siciliane)', 'White Blend', 'Stemmari', 2013, 'Sicily & Sardinia,Italy', 37.5999938, 14.0153557, 'White'), (4, 'Italy', 'Aromas recall ripe dark berry, toast and a whiff of cake spice. The soft, informal palate offers sour cherry, vanilla and a hint of espresso alongside round tannins. Drink soon.', 87, 10.0, 'Sicily & Sardinia', 'Terre Siciliane', 'Kerin O’Keefe', '@kerinokeefe', "Stemmari 2013 Nero d'Avola (Terre Siciliane)", "Nero d'Avola", 'Stemmari', 2013, 'Sicily & Sardinia,Italy', 37.5999938, 14.0153557, 'Red'), (5, 'Italy', 'Aromas suggest mature berry, scorched earth, animal, toast and anise. The palate offers ripe black berry, oak, espresso, cocoa and vanilla alongside dusty tannins.', 87, 17.0, 'Sicily & Sardinia', 'Cerasuolo di Vittoria', 'Kerin O’Keefe', '@kerinokeefe', 'Terre di Giurfo 2011 Mascaria Barricato  (Cerasuolo di Vittoria)', 'Red Blend', 'Terre di Giurfo', 2011, 'Sicily & Sardinia,Italy', 37.5999938, 14.0153557, 'Red'), (6, 'Italy', 'This concentrated Cabernet offers aromas of cured meat, dried fruit and rosemary. Barbecue spice and teriyaki sauce flavors give the wine a bold, chewy feel.', 86, 21.0, 'Sicily & Sardinia', 'Sicilia', 'N/A', 'N/A', 'Feudi del Pisciotto 2010 Missoni Cabernet Sauvignon (Sicilia)', 'Cabernet Sauvignon', 'Feudi del Pisciotto', 2010, 'Sicily & Sardinia,Italy', 37.5999938, 14.0153557, 'Red'), (7, 'Italy', 'Part of the natural wine movement, this wine is made from organic grapes, and the label is printed with vegetable ink on recycled paper. The quality of fruit is very nice, with a juicy palate and a bright berry flavor on the finish.', 86, 12.0, 'Sicily & Sardinia', 'Sicilia', 'N/A', 'N/A', "Feudo di Santa Tresa 2011 Purato Made With Organic Grapes Nero d'Avola (Sicilia)", "Nero d'Avola", 'Feudo di Santa Tresa', 2011, 'Sicily & Sardinia,Italy', 37.5999938, 14.0153557, 'Red')  ... displaying 10 of 114399 total bound parameter sets ...  (114397, 'Greece', 'Vanilla, orange marmalade and butterscotch aromas intrigue in this more voluptuous white. On the palate, flavors of butterscotch and orange peel are unique but the white could use a touch more balancing acidity. Overall though, this is a unique everyday wine.', 84, 14.0, 'Lesbos', 'N/A', 'Susan Kostrzewa', '@suskostrzewa', 'Methymnaeos 2010 Chidiriotiko Blanc de Noirs White (Lesbos)', 'White Blend', 'Methymnaeos', 2010, 'Lesbos,Greece ...
# 2020-11-08 20:46:25,794 INFO sqlalchemy.engine.base.Engine COMMIT
